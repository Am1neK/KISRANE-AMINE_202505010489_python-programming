# %% [markdown]
# START
# choice = "y"
#
# WHILE choice == "y" ==>Iteration
#
#    INPUT quiz1 ==>Input
#    INPUT quiz2 ==>Input
#    INPUT quiz3 ==>Input
#
#    average = (quiz1 + quiz2 + quiz3) / 3 ==>Process
#
#    DISPLAY average ==>Output
#
#    IF average >= 50 ==>Selection
#       DISPLAY "PASS" ==>Output
#    ELSE
#       DISPLAY "FAIL" ==>Output
#
#    INPUT choice ==>Input
# END WHILE
#
# DISPLAY "Program Ended" ==>gOutput
#
# END
